# %% [markdown]
# <a href="https://colab.research.google.com/github/fajarfat1195/property/blob/main/zoho_crm/zoho_crm_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import sys
from google.colab import drive

# 1. Mount Drive
drive.mount('/content/drive')

# 2. Tambahkan path folder tempat file .py berada
# Pastikan penulisannya persis (huruf besar/kecil berpengaruh)
path_to_module = '/content/drive/MyDrive/Colab Notebooks/property'
if path_to_module not in sys.path:
    sys.path.append(path_to_module)

# 3. Cek apakah file ada di sana (untuk memastikan)
# !ls '/content/drive/MyDrive/Colab Notebooks/property'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# __pycache__  Untitled0.ipynb  zoho_crm_api_module.py

# %%
# Import file .py Anda
try:
    import zoho_crm_api_module as crm
    print("Berhasil import modul Zoho!")
except ImportError as e:
    print(f"Gagal import: {e}")
# Out:
# Berhasil import modul Zoho!

# %%
cols = [
    'Created_Time',
    'id',
    'Last_Name',
    'Email',
    'Phone',
    'City',
    'Country',
    'Lead_Status',
    'Lead_Type1',
    'Agents'
]

# %%
crm_token = crm.get_crm_token()

# %%
crm_token
# Out:
# '1000.3340e839a2cdcfae4e6ee95424f95032.68373e927bc415ad92fe221d88fc0b04'

# %%
leads_df = crm.get_leads_data(crm_token, cols)
# df.fillna('empty', inplace=True)
leads_df
# Out:
#                   Created_Time                   id        Last_Name  \
# 0    2025-09-25T16:37:01+08:00  6965175000000864001  Jeffrey Slagter
# 1    2025-09-27T09:52:30+08:00  6965175000000909001    Linda Beamish
# 2    2025-09-28T00:33:03+08:00  6965175000000927001   Patrick Grauel
# 3    2025-09-28T14:27:06+08:00  6965175000000927020     Tolga Kartal
# 4    2025-09-30T20:12:45+08:00  6965175000001020001      William Ray
# ..                         ...                  ...              ...
# 239  2025-12-26T06:37:34+08:00  6965175000004197002   Esther V Arkel
# 240  2025-12-26T06:35:13+08:00  6965175000004209001     Esther Arkel
# 241  2025-12-27T11:46:03+08:00  6965175000004242001           Ju1103
# 242  2025-12-28T10:53:44+08:00  6965175000004261001           Ju1103
# 243  2025-12-30T13:58:56+08:00  6965175000004325001    David Warwick
#
#                            Email           Phone   City    Country  \
# 0    jeffrey.slagter92@gmail.com    +31615528811   None       None
# 1      lindaannbeamish@gmail.com      0418418444   None       None
# 2      patrick.grauel@outlook.de  00491728122120   None       None
# 3      tolga.kartal1@hotmail.com      0439397006   None       None
# 4           willamrray@gmail.com    +13035073932   None       None
# ..                           ...             ...    ...        ...
# 239       Es.van.arkel@gmail.com    +31633906806  Sanur  Indonesia
# 240       es.van.arkel@gmail.com    +62633906806   None       None
# 241        anombayan42@gmail.com  +6285921018966   None       None
# 242    nissiariowisesa@gmail.com  +6287888727188   None       None
# 243     davidwarwick21@gmail.com   +447595639709   None       None
#
#               Lead_Status Lead_Type1    Agents
# 0    Attempted to Contact       None      None
# 1    Attempted to Contact       None      None
# 2             No Response       None      None
# 3    Attempted to Contact       None      None
# 4    Attempted to Contact       None      None
# ..                    ...        ...       ...
# 239  Active Lead - abroad      Buyer      Suci
# 240  Active Lead - abroad      Buyer      Suci
# 241           No Response       None      None
# 242           No Response       None      None
# 243           No Response      Buyer  Juliette
#
# [244 rows x 10 columns]

# %%
leads_df.columns

# %%
filtered_df = crm.get_leads_data_filter(df)
filtered_df.replace('empty', '', inplace=True)

filtered_df
# filtered_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\push-past-guest-crm.xlsx', index=False)

# %%
# filtered_df.columns

seller_cols = [
    "Created_Time",
    "id",
    "Vendor_Name",
    "Owner_id",
    "Sellers_Account_type",
    "Email",
    "Phone",
    "City",
    "Country"
]

# %%
seller_df = crm.get_seller_account_data(crm_token, seller_cols)
# df.fillna('empty', inplace=True)
seller_df
