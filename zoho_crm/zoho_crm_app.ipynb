# %%
import requests

import pandas as pd

# importing
import zoho_crm_api_module as crm

import json
from pandas import json_normalize

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cols = [
    'Created_Time', 
    'id', 
    'First_Name', 
    'Last_Name', 
    'Email', 
    'Phone', 
    'Mobile', 
    'Brand', 
    'Lead_Sub_Brand', 
    'Lead_Source', 
    'Lead_Regions',
    'Lead_Locations', 
    'City', 
    'Nationality', 
    'Country', 
    'Booking_Status', 
    'Guest_Type', 
    'Email_Opt_In',
    'Email_Opt_Out', 
    'BookRef'
]

# %%
crm_token = crm.get_crm_token()

# %%
df = crm.get_past_guest_data(crm_token, cols)
df.fillna('empty', inplace=True)
df
# Out:
# /Users/dewiindahpurnama_/Documents/Python/property/zoho_crm/zoho_crm_api_module.py:64: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   concat_df['Lead_Locations'].replace('\[|\]|\'','', regex=True, inplace=True)
#                 Created_Time                   id       First_Name  \
# 0  2022-12-23T17:14:26+08:00  3584690000418923434         Patricia
# 1  2022-12-23T04:17:27+08:00  3584690000418924292  Jemma Humphreys
# 2  2022-12-23T18:20:21+08:00  3584690000419011431            Ellie
# 3  2022-12-23T06:03:45+08:00  3584690000419013106             Lucy
# 4  2022-12-23T23:19:51+08:00  3584690000419178028           Kuppan
#
#          Last_Name                            Email          Phone Mobile  \
# 0   De Lima Moraes  patricia-limamoraes@hotmail.com     6590895206  empty
# 1  Jemma Humphreys   jemma.humphreys@rocketmail.com  +447935901436  empty
# 2          Oreilly         ellieoreilly91@gmail.com   +61417185918  empty
# 3         Johnston           lucejohnston@gmail.com    64278457365  empty
# 4                E               kuppan10@gmail.com   919942128119  empty
#
#            Brand Lead_Sub_Brand  Lead_Source Lead_Regions      Lead_Locations  \
# 0  Karma Resorts          Other  Web Enquiry        Other       Karma Kandara
# 1  Karma Resorts          Other  Web Enquiry    UK/Europe  Karma Salford Hall
# 2  Karma Resorts          Other  Web Enquiry         SEAP       Karma Kandara
# 3  Karma Resorts          Other  Web Enquiry         SEAP       Karma Kandara
# 4  Karma Resorts          Other  Web Enquiry        empty               empty
#
#     City Nationality         Country Booking_Status Guest_Type  Email_Opt_In  \
# 0  empty       empty       Singapore          empty      empty          True
# 1  empty       empty  United Kingdom          empty      empty          True
# 2  empty       empty       Australia          empty      empty          True
# 3  empty       empty     New Zealand          empty      empty          True
# 4  empty       empty           empty          empty      empty         False
#
#    Email_Opt_Out BookRef
# 0          False   empty
# 1          False   empty
# 2          False   empty
# 3          False   empty
# 4          False   empty

# %%
df.columns
# Out:
# Index(['Created_Time', 'id', 'First_Name', 'Last_Name', 'Email', 'Phone',
#        'Mobile', 'Brand', 'Lead_Sub_Brand', 'Lead_Source', 'Lead_Regions',
#        'Lead_Locations', 'City', 'Nationality', 'Country', 'Booking_Status',
#        'Guest_Type', 'Email_Opt_In', 'Email_Opt_Out', 'BookRef'],
#       dtype='object')

# %%
new_df = crm.get_past_guest_data_filter(df)
new_df.replace('empty', '', inplace=True)

new_df
# new_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\push-past-guest-crm.xlsx', index=False)
# Out:
# Empty DataFrame
# Columns: [Created_Time, id, First_Name, Last_Name, Email, Phone, Mobile, Brand, Lead_Sub_Brand, Lead_Source, Lead_Regions, Lead_Locations, City, Nationality, Country, Booking_Status, Guest_Type, Email_Opt_In, Email_Opt_Out, BookRef]
# Index: []

# %%
new_df.columns
# Out:
# Index(['Created_Time', 'id', 'First_Name', 'Last_Name', 'Email', 'Phone',
#        'Mobile', 'Brand', 'Lead_Sub_Brand', 'Lead_Source', 'Lead_Regions',
#        'Lead_Locations', 'City', 'Nationality', 'Country', 'Booking_Status',
#        'Guest_Type', 'Email_Opt_In', 'Email_Opt_Out', 'BookRef'],
#       dtype='object')
